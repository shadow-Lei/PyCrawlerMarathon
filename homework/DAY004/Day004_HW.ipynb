# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %% [markdown]
# ### 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異

# %%
import requests
r = requests.get('https://api.github.com/events')
print(r.text)
# Out:
# [{"id":"15094438069","type":"CreateEvent","actor":{"id":64992967,"login":"ngillis13","display_login":"ngillis13","gravatar_id":"","url":"https://api.github.com/users/ngillis13","avatar_url":"https://avatars.githubusercontent.com/u/64992967?"},"repo":{"id":336717071,"name":"ngillis13/CP-1-Issues_website","url":"https://api.github.com/repos/ngillis13/CP-1-Issues_website"},"payload":{"ref":null,"ref_type":"repository","master_branch":"main","description":null,"pusher_type":"user"},"public":true,"created_at":"2021-02-07T06:23:27Z"},{"id":"15094438061","type":"PushEvent","actor":{"id":60054130,"login":"Ranjan2104","display_login":"Ranjan2104","gravatar_id":"","url":"https://api.github.com/users/Ranjan2104","avatar_url":"https://avatars.githubusercontent.com/u/60054130?"},"repo":{"id":331258618,"name":"Ranjan2104/Java-Programming-Codes","url":"https://api.github.com/repos/Ranjan2104/Java-Programming-Codes"},"payload":{"push_id":6488318769,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"fd2f715a51a621f24b6ee7090ff584f0e9eb95a6","before":"d97f10e6a3f1e003f76e295c61bff7bfac233db5","commits":[{"sha":"fd2f715a51a621f24b6ee7090ff584f0e9eb95a6","author":{"email":"60054130+Ranjan2104@users.noreply.github.com","name":"Amresh2104"},"message":"Create Union Array.txt","distinct":true,"url":"https://api.github.com/repos/Ranjan2104/Java-Programming-Codes/commits/fd2f715a51a621f24b6ee7090ff584f0e9eb95a6"}]},"public":true,"created_at":"2021-02-07T06:23:27Z"},{"id":"15094438063","type":"WatchEvent","actor":{"id":13678847,"login":"mitian233","display_login":"mitian233","gravatar_id":"","url":"https://api.github.com/users/mitian233","avatar_url":"https://avatars.githubusercontent.com/u/13678847?"},"repo":{"id":336687726,"name":"piae-mentes-project/Spectrograph","url":"https://api.github.com/repos/piae-mentes-project/Spectrograph"},"payload":{"action":"started"},"public":true,"created_at":"2021-02-07T06:23:27Z","org":{"id":78671379,"login":"piae-mentes-project","gravatar_id":"","url":"https://api.github.com/orgs/piae-mentes-project","avatar_url":"https://avatars.githubusercontent.com/u/78671379?"}},{"id":"15094438054","type":"PushEvent","actor":{"id":78495606,"login":"Gabrie29","display_login":"Gabrie29","gravatar_id":"","url":"https://api.github.com/users/Gabrie29","avatar_url":"https://avatars.githubusercontent.com/u/78495606?"},"repo":{"id":336717061,"name":"Gabrie29/camachoterrtwoo5","url":"https://api.github.com/repos/Gabrie29/camachoterrtwoo5"},"payload":{"push_id":6488318767,"size":1,"distinct_size":1,"ref":"refs/heads/main","head":"cdd153932ece2ddd87550253e40a483653133215","before":"e1978c1ba85dd4df81cdde57002557391227ddba","commits":[{"sha":"cdd153932ece2ddd87550253e40a483653133215","author":{"email":"78495606+Gabrie29@users.noreply.github.com","name":"Gabrie29"},"message":"uploading a file","distinct":true,"url":"https://api.github.com/repos/Gabrie29/camachoterrtwoo5/commits/cdd153932ece2ddd87550253e40a483653133215"}]},"public":true,"created_at":"2021-02-07T06:23:27Z"},{"id":"15094438051","type":"WatchEvent","actor":{"id":241508,"login":"zhanglei","display_login":"zhanglei","gravatar_id":"","url":"https://api.github.com/users/zhanglei","avatar_url":"https://avatars.githubusercontent.com/u/241508?"},"repo":{"id":80814174,"name":"jgsqware/wrk-report","url":"https://api.github.com/repos/jgsqware/wrk-report"},"payload":{"action":"started"},"public":true,"created_at":"2021-02-07T06:23:27Z"},{"id":"15094438050","type":"PushEvent","actor":{"id":6371317,"login":"baberrehman","display_login":"baberrehman","gravatar_id":"","url":"https://api.github.com/users/baberrehman","avatar_url":"https://avatars.githubusercontent.com/u/6371317?"},"repo":{"id":253216451,"name":"baberrehman/disjoint-union","url":"https://api.github.com/repos/baberrehman/disjoint-union"},"payload":{"push_id":6488318766,"size":1,"distinct_size":1,"ref":"refs/heads/master","head":"355a24dc6b093a14bb65902687bd34ff28f9a70e","before":"a30c36b89a679ccfabf50632a20a0e9301e806f1"," ...

# %%
import json

json.loads(r.text)
# Out:
# [{'id': '15094438069',
#   'type': 'CreateEvent',
#   'actor': {'id': 64992967,
#    'login': 'ngillis13',
#    'display_login': 'ngillis13',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ngillis13',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/64992967?'},
#   'repo': {'id': 336717071,
#    'name': 'ngillis13/CP-1-Issues_website',
#    'url': 'https://api.github.com/repos/ngillis13/CP-1-Issues_website'},
#   'payload': {'ref': None,
#    'ref_type': 'repository',
#    'master_branch': 'main',
#    'description': None,
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-02-07T06:23:27Z'},
#  {'id': '15094438061',
#   'type': 'PushEvent',
#   'actor': {'id': 60054130,
#    'login': 'Ranjan2104',
#    'display_login': 'Ranjan2104',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Ranjan2104',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/60054130?'},
#   'repo': {'id': 331258618,
#    'name': 'Ranjan2104/Java-Programming-Codes',
#    'url': 'https://api.github.com/repos/Ranjan2104/Java-Programming-Codes'},
#   'payload': {'push_id': 6488318769,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'fd2f715a51a621f24b6ee7090ff584f0e9eb95a6',
#    'before': 'd97f10e6a3f1e003f76e295c61bff7bfac233db5',
#    'commits': [{'sha': 'fd2f715a51a621f24b6ee7090ff584f0e9eb95a6',
#      'author': {'email': '60054130+Ranjan2104@users.noreply.github.com',
#       'name': 'Amresh2104'},
#      'message': 'Create Union Array.txt',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Ranjan2104/Java-Programming-Codes/commits/fd2f715a51a621f24b6ee7090ff584f0e9eb95a6'}]},
#   'public': True,
#   'created_at': '2021-02-07T06:23:27Z'},
#  {'id': '15094438063',
#   'type': 'WatchEvent',
#   'actor': {'id': 13678847,
#    'login': 'mitian233',
#    'display_login': 'mitian233',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mitian233',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/13678847?'},
#   'repo': {'id': 336687726,
#    'name': 'piae-mentes-project/Spectrograph',
#    'url': 'https://api.github.com/repos/piae-mentes-project/Spectrograph'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2021-02-07T06:23:27Z',
#   'org': {'id': 78671379,
#    'login': 'piae-mentes-project',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/piae-mentes-project',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/78671379?'}},
#  {'id': '15094438054',
#   'type': 'PushEvent',
#   'actor': {'id': 78495606,
#    'login': 'Gabrie29',
#    'display_login': 'Gabrie29',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Gabrie29',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/78495606?'},
#   'repo': {'id': 336717061,
#    'name': 'Gabrie29/camachoterrtwoo5',
#    'url': 'https://api.github.com/repos/Gabrie29/camachoterrtwoo5'},
#   'payload': {'push_id': 6488318767,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'cdd153932ece2ddd87550253e40a483653133215',
#    'before': 'e1978c1ba85dd4df81cdde57002557391227ddba',
#    'commits': [{'sha': 'cdd153932ece2ddd87550253e40a483653133215',
#      'author': {'email': '78495606+Gabrie29@users.noreply.github.com',
#       'name': 'Gabrie29'},
#      'message': 'uploading a file',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Gabrie29/camachoterrtwoo5/commits/cdd153932ece2ddd87550253e40a483653133215'}]},
#   'public': True,
#   'created_at': '2021-02-07T06:23:27Z'},
#  {'id': '15094438051',
#   'type': 'WatchEvent',
#   'actor': {'id': 241508,
#    'login': 'zhanglei',
#    'display_login': 'zhanglei',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/zhanglei',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/241508?'},
#   'repo': {'id': 80814174,
#    'name': 'jgsqware/wrk-report',
#    'url': 'https://api.github.com/repos/jgsqware/wrk-report'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2021-02-07T06:23:27Z'},
#  {'id': '15094438050',
#   'type': 'PushEvent',
#   'actor': {'id': 6371317,
#    'login': 'baberrehman',
#    'display_login': 'baberrehman',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/baberrehman',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/6371317?'},
#   'repo': {'id': 253216451,
#    'name': 'baberrehman/disjoint-union',
#    'url': 'https://api.github.com/repos/baberrehman/disjoint-union'},
#   'payload': {'push_id': 6488318766,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '355a24dc6b093a14bb65902687bd34ff28f9a70e',
#    'before': 'a30c36b89a679ccfabf50632a20a0e9301e806f1',
#    'commits': [{'sha': '355a24dc6b093a14bb65902687bd34ff28f9a70e',
#      'author': {'email': 'baberrehman26@gmail.com', 'name': 'baberrehman'},
#      'message': 'reflexivity',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/baberrehman/disjoint-union/commits/355a24dc6b093a14bb65902687bd34ff28f9a70e'}]},
#   'public': True,
#   'created_at': '2021-02-07T06:23:27Z'},
#  {'id': '15094438049',
#   'type': 'CreateEvent',
#   'actor': {'id': 49275095,
#    'login': 'ursabot',
#    'display_login': 'ursabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ursabot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49275095?'},
#   'repo': {'id': 328697653,
#    'name': 'ursacomputing/crossbow',
#    'url': 'https://api.github.com/repos/ursacomputing/crossbow'},
#   'payload': {'ref': 'nightly-2021-02-07-0-github-test-conda-python-3.7-turbodbc-master',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'Extra CI for Apache Arrow',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-02-07T06:23:27Z',
#   'org': {'id': 70039053,
#    'login': 'ursacomputing',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/ursacomputing',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/70039053?'}},
#  {'id': '15094438047',
#   'type': 'WatchEvent',
#   'actor': {'id': 42827632,
#    'login': 'KumarAbhishekRaj',
#    'display_login': 'KumarAbhishekRaj',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/KumarAbhishekRaj',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/42827632?'},
#   'repo': {'id': 146764679,
#    'name': 'rawaniharsh/Aravali_alumni_android_app',
#    'url': 'https://api.github.com/repos/rawaniharsh/Aravali_alumni_android_app'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2021-02-07T06:23:27Z'},
#  {'id': '15094438040',
#   'type': 'CreateEvent',
#   'actor': {'id': 50618606,
#    'login': 'hmcts-flux-sandbox',
#    'display_login': 'hmcts-flux-sandbox',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/hmcts-flux-sandbox',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/50618606?'},
#   'repo': {'id': 172700355,
#    'name': 'hmcts/cnp-flux-config',
#    'url': 'https://api.github.com/repos/hmcts/cnp-flux-config'},
#   'payload': {'ref': 'flux-write-check-44dc495e86',
#    'ref_type': 'tag',
#    'master_branch': 'master',
#    'description': 'FluxCD Flux config for AKS clusters',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-02-07T06:23:27Z',
#   'org': {'id': 22817111,
#    'login': 'hmcts',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/hmcts',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/22817111?'}},
#  {'id': '15094438035',
#   'type': 'PushEvent',
#   'actor': {'id': 5438200,
#    'login': 'ulibarri',
#    'display_login': 'ulibarri',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ulibarri',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/5438200?'},
#   'repo': {'id': 284509051,
#    'name': 'ulibarri/covidcolima',
#    'url': 'https://api.github.com/repos/ulibarri/covidcolima'},
#   'payload': {'push_id': 6488318763,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '6a86bd7c3b9e790ef79c7b0ebb811c81705be881',
#    'before': '11b80ef9c2349094ba84a049bd50aea6aa56daf9',
#    'commits': [{'sha': '6a86bd7c3b9e790ef79c7b0ebb811c81705be881',
#      'author': {'email': 'ulibarriireta@gmail.com', 'name': 'ulibarri'},
#      'message': 'feb 6th update',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ulibarri/covidcolima/commits/6a86bd7c3b9e790ef79c7b0ebb811c81705be881'}]},
#   'public': True,
#   'created_at': '2021-02-07T06:23:27Z'},
#  {'id': '15094438034',
#   'type': 'PushEvent',
#   'actor': {'id': 46369225,
#    'login': 'qibebt-bioinfo',
#    'display_login': 'qibebt-bioinfo',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/qibebt-bioinfo',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/46369225?'},
#   'repo': {'id': 323485904,
#    'name': 'qibebt-bioinfo/bioconda-recipes',
#    'url': 'https://api.github.com/repos/qibebt-bioinfo/bioconda-recipes'},
#   'payload': {'push_id': 6488318756,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/dms',
#    'head': '763d33f63b46cee6de25623dee81f97621912b93',
#    'before': 'bb6b4319ecfc3721ee5bd00d20f4e4caa2c0cc55',
#    'commits': [{'sha': '763d33f63b46cee6de25623dee81f97621912b93',
#      'author': {'email': '937721540@qq.com', 'name': 'bambam'},
#      'message': 'modify meta.yaml',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/qibebt-bioinfo/bioconda-recipes/commits/763d33f63b46cee6de25623dee81f97621912b93'}]},
#   'public': True,
#   'created_at': '2021-02-07T06:23:27Z'},
#  {'id': '15094438030',
#   'type': 'PushEvent',
#   'actor': {'id': 3490170,
#    'login': 'DotnetChen',
#    'display_login': 'DotnetChen',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/DotnetChen',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3490170?'},
#   'repo': {'id': 238119324,
#    'name': 'DotnetChen/mohw-mask',
#    'url': 'https://api.github.com/repos/DotnetChen/mohw-mask'},
#   'payload': {'push_id': 6488318758,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '08b83283d9e082758dcf353a5418434c6f2a58ee',
#    'before': '43d4c73ff747d271018e804946752b261da95654',
#    'commits': [{'sha': '08b83283d9e082758dcf353a5418434c6f2a58ee',
#      'author': {'email': 'pupu721@gmail.com', 'name': 'Pupu(DotNet)'},
#      'message': '更新 maskdata_auto.csv (from auto)',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/DotnetChen/mohw-mask/commits/08b83283d9e082758dcf353a5418434c6f2a58ee'}]},
#   'public': True,
#   'created_at': '2021-02-07T06:23:27Z'},
#  {'id': '15094438023',
#   'type': 'PushEvent',
#   'actor': {'id': 8517910,
#    'login': 'LombiqBot',
#    'display_login': 'LombiqBot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/LombiqBot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8517910?'},
#   'repo': {'id': 264190944,
#    'name': 'Lombiq/Orchard.AngularJS',
#    'url': 'https://api.github.com/repos/Lombiq/Orchard.AngularJS'},
#   'payload': {'push_id': 6488318754,
#    'size': 0,
#    'distinct_size': 0,
#    'ref': 'refs/heads/orchard-upgrade-1.9.2',
#    'head': 'bce214068f9be777be423395cb571c167fcaa241',
#    'before': 'bce214068f9be777be423395cb571c167fcaa241',
#    'commits': []},
#   'public': True,
#   'created_at': '2021-02-07T06:23:27Z',
#   'org': {'id': 8158177,
#    'login': 'Lombiq',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/Lombiq',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8158177?'}},
#  {'id': '15094438021',
#   'type': 'PushEvent',
#   'actor': {'id': 312455,
#    'login': 'beejjorgensen',
#    'display_login': 'beejjorgensen',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/beejjorgensen',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/312455?'},
#   'repo': {'id': 114574741,
#    'name': 'beejjorgensen/bgc',
#    'url': 'https://api.github.com/repos/beejjorgensen/bgc'},
#   'payload': {'push_id': 6488318749,
#    'size': 3,
#    'distinct_size': 3,
#    'ref': 'refs/heads/master',
#    'head': 'aac05a66d65e669ae14a2ce71ee7736fb8dae05b',
#    'before': 'a23c52286a0c3186387454c1f0ccc75183f1cb10',
#    'commits': [{'sha': '8f19199d8864c66f4cd66a09f22308fc1893caf1',
#      'author': {'email': 'beej@beej.us',
#       'name': 'Brian "Beej Jorgensen" Hall'},
#      'message': 'add ln',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/beejjorgensen/bgc/commits/8f19199d8864c66f4cd66a09f22308fc1893caf1'},
#     {'sha': 'd98e403d94600d4749375d8d325b55f4f5565efc',
#      'author': {'email': 'beej@beej.us',
#       'name': 'Brian "Beej Jorgensen" Hall'},
#      'message': 'fix missing DECIMAL_DIG stuff',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/beejjorgensen/bgc/commits/d98e403d94600d4749375d8d325b55f4f5565efc'},
#     {'sha': 'aac05a66d65e669ae14a2ce71ee7736fb8dae05b',
#      'author': {'email': 'beej@beej.us',
#       'name': 'Brian "Beej Jorgensen" Hall'},
#      'message': 'log1p',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/beejjorgensen/bgc/commits/aac05a66d65e669ae14a2ce71ee7736fb8dae05b'}]},
#   'public': True,
#   'created_at': '2021-02-07T06:23:27Z'},
#  {'id': '15094438020',
#   'type': 'PushEvent',
#   'actor': {'id': 78674827,
#    'login': 'MustafizurAnik',
#    'display_login': 'MustafizurAnik',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/MustafizurAnik',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/78674827?'},
#   'repo': {'id': 336716628,
#    'name': 'MustafizurAnik/nayem......-',
#    'url': 'https://api.github.com/repos/MustafizurAnik/nayem......-'},
#   'payload': {'push_id': 6488318752,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '16ee1a8da6edf85b14499f275e401fd55f66ed32',
#    'before': '4a0fdae72fe3fed2320fe8e4ca870d892ce081ce',
#    'commits': [{'sha': '16ee1a8da6edf85b14499f275e401fd55f66ed32',
#      'author': {'email': 'anik@floorfly.com', 'name': 'MustafizurAnik'},
#      'message': 'Create FF-PR-139.png',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/MustafizurAnik/nayem......-/commits/16ee1a8da6edf85b14499f275e401fd55f66ed32'}]},
#   'public': True,
#   'created_at': '2021-02-07T06:23:27Z'},
#  {'id': '15094438016',
#   'type': 'PushEvent',
#   'actor': {'id': 68417258,
#    'login': 'breakingheatmap',
#    'display_login': 'breakingheatmap',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/breakingheatmap',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/68417258?'},
#   'repo': {'id': 280356388,
#    'name': 'breakingheatmap/breakingheatmap',
#    'url': 'https://api.github.com/repos/breakingheatmap/breakingheatmap'},
#   'payload': {'push_id': 6488318753,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'd3cd8a9d742e079c726a0f6a432ef4ec78da4c44',
#    'before': '6f5306d60399efdf45b611d2c3a15da8b931b453',
#    'commits': [{'sha': 'd3cd8a9d742e079c726a0f6a432ef4ec78da4c44',
#      'author': {'email': 'sudomaze@gmail.com', 'name': 'sudomaze'},
#      'message': '1612679003',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/breakingheatmap/breakingheatmap/commits/d3cd8a9d742e079c726a0f6a432ef4ec78da4c44'}]},
#   'public': True,
#   'created_at': '2021-02-07T06:23:27Z'},
#  {'id': '15094438015',
#   'type': 'WatchEvent',
#   'actor': {'id': 60533173,
#    'login': 'peterxli',
#    'display_login': 'peterxli',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/peterxli',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/60533173?'},
#   'repo': {'id': 331926236,
#    'name': 'itdevbooks/pdf',
#    'url': 'https://api.github.com/repos/itdevbooks/pdf'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2021-02-07T06:23:27Z'},
#  {'id': '15094438010',
#   'type': 'PushEvent',
#   'actor': {'id': 41898282,
#    'login': 'github-actions[bot]',
#    'display_login': 'github-actions',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/github-actions[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/41898282?'},
#   'repo': {'id': 282381768,
#    'name': 'winnieking/AutoApiSecret',
#    'url': 'https://api.github.com/repos/winnieking/AutoApiSecret'},
#   'payload': {'push_id': 6488318745,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/main',
#    'head': 'ea51c8508002cc18f2a1833d97ec6781950b91f6',
#    'before': '1584f0a8cacf5e7343ac59fa71b4615b581b2abd',
#    'commits': [{'sha': 'ea51c8508002cc18f2a1833d97ec6781950b91f6',
#      'author': {'email': 'AutoupdateRobot@email.com',
#       'name': 'AutoupdateRobot'},
#      'message': 'update new refresh_token',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/winnieking/AutoApiSecret/commits/ea51c8508002cc18f2a1833d97ec6781950b91f6'}]},
#   'public': True,
#   'created_at': '2021-02-07T06:23:26Z'},
#  {'id': '15094438005',
#   'type': 'PushEvent',
#   'actor': {'id': 76729791,
#    'login': 'GenieWonimanimo',
#    'display_login': 'GenieWonimanimo',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/GenieWonimanimo',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/76729791?'},
#   'repo': {'id': 325825775,
#    'name': 'GenieWonimanimo/BOJ',
#    'url': 'https://api.github.com/repos/GenieWonimanimo/BOJ'},
#   'payload': {'push_id': 6488318742,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'e2e693c279078b251125468a9d8db76d7d13861a',
#    'before': 'ae8de68eab975745c0f7a364db91665aad6dbbbe',
#    'commits': [{'sha': 'e2e693c279078b251125468a9d8db76d7d13861a',
#      'author': {'email': 'kor98won@gmail.com', 'name': 'jiweon'},
#      'message': '큐',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/GenieWonimanimo/BOJ/commits/e2e693c279078b251125468a9d8db76d7d13861a'}]},
#   'public': True,
#   'created_at': '2021-02-07T06:23:26Z'},
#  {'id': '15094438003',
#   'type': 'PushEvent',
#   'actor': {'id': 2605401,
#    'login': 'kenjinote',
#    'display_login': 'kenjinote',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kenjinote',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/2605401?'},
#   'repo': {'id': 331655829,
#    'name': 'henkan-site/henkan-site.github.io',
#    'url': 'https://api.github.com/repos/henkan-site/henkan-site.github.io'},
#   'payload': {'push_id': 6488318741,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '1cdf3d6378f96875b246d1ab6562b94fe87cbc4b',
#    'before': '8769373edfcf3aadb6edee314263fc561dc44741',
#    'commits': [{'sha': '1cdf3d6378f96875b246d1ab6562b94fe87cbc4b',
#      'author': {'email': 'kenji256@gmail.com', 'name': 'kenjinote'},
#      'message': '円グラフ生成ページを追加',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/henkan-site/henkan-site.github.io/commits/1cdf3d6378f96875b246d1ab6562b94fe87cbc4b'}]},
#   'public': True,
#   'created_at': '2021-02-07T06:23:26Z',
#   'org': {'id': 77791755,
#    'login': 'henkan-site',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/henkan-site',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/77791755?'}},
#  {'id': '15094438008',
#   'type': 'PullRequestReviewCommentEvent',
#   'actor': {'id': 14783759,
#    'login': 'ulfrid',
#    'display_login': 'ulfrid',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ulfrid',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/14783759?'},
#   'repo': {'id': 277517763,
#    'name': 'wecode-bootcamp-korea/westagram-backend',
#    'url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend'},
#   'payload': {'action': 'created',
#    'comment': {'url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/pulls/comments/571558522',
#     'pull_request_review_id': 584969447,
#     'id': 571558522,
#     'node_id': 'MDI0OlB1bGxSZXF1ZXN0UmV2aWV3Q29tbWVudDU3MTU1ODUyMg==',
#     'diff_hunk': "@@ -0,0 +1,65 @@\n+import json, re, bcrypt, jwt\n+\n+from django.http     import JsonResponse\n+from django.views    import View\n+\n+from .models         import Account\n+\n+MINIMUN_PASSWORD_LENGTH = 8\n+\n+class UserSignUpView(View):\n+    def post(self, request):\n+        try:\n+            data       = json.loads(request.body)\n+            username   = data.get('username', None)\n+            email      = data.get('email', None)\n+            password   = data.get('password', None)\n+            phone_num  = data.get('phone_num', None)\n+\n+            if email and password:\n+                email_form = re.compile('^[a-zA-Z0-9+-_.]+@[a-zA-Z0-9-]+\\.[a-zA-Z0-9-.]+$')\n+                \n+                if not email_form.match(str(email)):\n+                    return JsonResponse({'MESSSAGE': 'INVALID_EMAIL'}, status=400)\n+\n+                if len(password) < MINIMUN_PASSWORD_LENGTH:\n+                    return JsonResponse({'MESSSAGE': 'PASSWORD_IS_SHORT'}, status=400)\n+\n+                if Account.objects.filter(email=data['email']).exists():\n+                    return JsonResponse({'MESSSAGE': 'ALREADY_USE_EMAIL'}, status=400)\n+\n+                user_data = Account.objects.create(\n+                        username   = username,\n+                        email      = email,\n+                        password   = bcrypt.hashpw(password.encode('utf-8'), bcrypt.gensalt()),\n+                        phone_num  = phone_num\n+                        )\n+                return JsonResponse({'MESSSAGE': 'SUCCESS'}, status=200)\n+\n+            return JsonResponse({'MESSSAGE': 'KEY_ERROR'}, status=400)\n+\n+        except KeyError:\n+            return JsonResponse({'MESSSAGE': 'KEY_ERROR'}, status=400)\n+\n+class UserSignInView(View):\n+    def post(self, request):\n+        try:\n+            data      = json.loads(request.body)\n+            #username  = data['username']\n+            email     = data['email']\n+            password  = data['password']\n+            #phone_num = data['phone_num']",
#     'path': 'students/17th/raon/chaerin/user/views.py',
#     'position': 51,
#     'original_position': 51,
#     'commit_id': '3c5fbe39e45529715998d870603c121aa780d4a3',
#     'original_commit_id': '3c5fbe39e45529715998d870603c121aa780d4a3',
#     'user': {'login': 'ulfrid',
#      'id': 14783759,
#      'node_id': 'MDQ6VXNlcjE0NzgzNzU5',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/14783759?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/ulfrid',
#      'html_url': 'https://github.com/ulfrid',
#      'followers_url': 'https://api.github.com/users/ulfrid/followers',
#      'following_url': 'https://api.github.com/users/ulfrid/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/ulfrid/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/ulfrid/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/ulfrid/subscriptions',
#      'organizations_url': 'https://api.github.com/users/ulfrid/orgs',
#      'repos_url': 'https://api.github.com/users/ulfrid/repos',
#      'events_url': 'https://api.github.com/users/ulfrid/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/ulfrid/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': "```suggestion\r\n            #phone_num = data['phone_num']\r\n```\r\n마찬가지입니다.",
#     'created_at': '2021-02-07T06:23:04Z',
#     'updated_at': '2021-02-07T06:23:26Z',
#     'html_url': 'https://github.com/wecode-bootcamp-korea/westagram-backend/pull/208#discussion_r571558522',
#     'pull_request_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/pulls/208',
#     'author_association': 'CONTRIBUTOR',
#     '_links': {'self': {'href': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/pulls/comments/571558522'},
#      'html': {'href': 'https://github.com/wecode-bootcamp-korea/westagram-backend/pull/208#discussion_r571558522'},
#      'pull_request': {'href': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/pulls/208'}},
#     'start_line': None,
#     'original_start_line': None,
#     'start_side': None,
#     'line': 51,
#     'original_line': 51,
#     'side': 'RIGHT'},
#    'pull_request': {'url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/pulls/208',
#     'id': 565117877,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0NTY1MTE3ODc3',
#     'html_url': 'https://github.com/wecode-bootcamp-korea/westagram-backend/pull/208',
#     'diff_url': 'https://github.com/wecode-bootcamp-korea/westagram-backend/pull/208.diff',
#     'patch_url': 'https://github.com/wecode-bootcamp-korea/westagram-backend/pull/208.patch',
#     'issue_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/issues/208',
#     'number': 208,
#     'state': 'open',
#     'locked': False,
#     'title': '[남채린] Mission 3 : 로그인 엔드포인트',
#     'user': {'login': 'namchaerin',
#      'id': 75118691,
#      'node_id': 'MDQ6VXNlcjc1MTE4Njkx',
#      'avatar_url': 'https://avatars.githubusercontent.com/u/75118691?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/namchaerin',
#      'html_url': 'https://github.com/namchaerin',
#      'followers_url': 'https://api.github.com/users/namchaerin/followers',
#      'following_url': 'https://api.github.com/users/namchaerin/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/namchaerin/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/namchaerin/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/namchaerin/subscriptions',
#      'organizations_url': 'https://api.github.com/users/namchaerin/orgs',
#      'repos_url': 'https://api.github.com/users/namchaerin/repos',
#      'events_url': 'https://api.github.com/users/namchaerin/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/namchaerin/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'body': '>wecode PR message template 및 체크 리스트 입니다. \r\n아래 사항들을 전부 작성/체크 하시고 PR 해주세요!\r\n\r\n## 수정 사항 간략한 한줄 요약\r\n(여기에 수정 사항에 대한 간략한 한줄 요약/제목 작성해 주세요.)\r\n- 회원가입 엔드포인트 구현\r\n\t\t \r\n## 수정 사항들 자세한 내용\r\n(여기에 수정 사항에 대한 자세한 내용을 작성해 주세요.)\r\n- 이메일, 비밀번호 필수\r\n- 에러 반환\r\n\r\n## 기타 질문 및 특이 사항\r\n(궁금한 사항들, 하면서 느낀 점들 공유해주실 것이 있으면 자유롭게 작성해 주세요.)\r\n\r\n\r\n## 체크 리스트 (아래 사항들이 전부 체크되어야만 merge가 됩니다!)\r\n조건을 만족한다면 각 빈칸에 x 표시 해주세요\r\n- [x] 필요한 test들을 완료하였고 기능이 제대로 실행되는지 확인 하였습니다.\r\n- [x] Wecode의 코드 스타일 가이드에 맞추어 코드를 작성 하였습니다.\r\n- [x] 제가 의도한 파일들과 수정 사항들만 커밋이 된 것을 확인 하였습니다.\r\n- [x] 본 수정 사항들을 팀원들과 사전에 상의하였고 팀원들 모두 해당 PR에 대하여 알고 있습니다.\r\n',
#     'created_at': '2021-02-01T11:50:45Z',
#     'updated_at': '2021-02-07T06:23:26Z',
#     'closed_at': None,
#     'merged_at': None,
#     'merge_commit_sha': 'ebef8102799e5239411696571e544983c1c2a3fa',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [{'id': 2184470984,
#       'node_id': 'MDU6TGFiZWwyMTg0NDcwOTg0',
#       'url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/labels/Status%20:%20%EB%A6%AC%EB%B7%B0%20%EC%9A%94%EC%B2%AD',
#       'name': 'Status : 리뷰 요청',
#       'color': '7057ff',
#       'default': False,
#       'description': '리뷰 요청'},
#      {'id': 2184470974,
#       'node_id': 'MDU6TGFiZWwyMTg0NDcwOTc0',
#       'url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/labels/%ED%95%84%EC%88%98%20%EA%B5%AC%ED%98%84%20%EC%82%AC%ED%95%AD',
#       'name': '필수 구현 사항',
#       'color': 'd73a4a',
#       'default': False,
#       'description': ''}],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/pulls/208/commits',
#     'review_comments_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/pulls/208/comments',
#     'review_comment_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/issues/208/comments',
#     'statuses_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/statuses/3c5fbe39e45529715998d870603c121aa780d4a3',
#     'head': {'label': 'wecode-bootcamp-korea:feature/chaerin',
#      'ref': 'feature/chaerin',
#      'sha': '3c5fbe39e45529715998d870603c121aa780d4a3',
#      'user': {'login': 'wecode-bootcamp-korea',
#       'id': 52394741,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjUyMzk0NzQx',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/52394741?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/wecode-bootcamp-korea',
#       'html_url': 'https://github.com/wecode-bootcamp-korea',
#       'followers_url': 'https://api.github.com/users/wecode-bootcamp-korea/followers',
#       'following_url': 'https://api.github.com/users/wecode-bootcamp-korea/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/wecode-bootcamp-korea/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/wecode-bootcamp-korea/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/wecode-bootcamp-korea/subscriptions',
#       'organizations_url': 'https://api.github.com/users/wecode-bootcamp-korea/orgs',
#       'repos_url': 'https://api.github.com/users/wecode-bootcamp-korea/repos',
#       'events_url': 'https://api.github.com/users/wecode-bootcamp-korea/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/wecode-bootcamp-korea/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 277517763,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyNzc1MTc3NjM=',
#       'name': 'westagram-backend',
#       'full_name': 'wecode-bootcamp-korea/westagram-backend',
#       'private': False,
#       'owner': {'login': 'wecode-bootcamp-korea',
#        'id': 52394741,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjUyMzk0NzQx',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/52394741?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/wecode-bootcamp-korea',
#        'html_url': 'https://github.com/wecode-bootcamp-korea',
#        'followers_url': 'https://api.github.com/users/wecode-bootcamp-korea/followers',
#        'following_url': 'https://api.github.com/users/wecode-bootcamp-korea/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/wecode-bootcamp-korea/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/wecode-bootcamp-korea/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/wecode-bootcamp-korea/subscriptions',
#        'organizations_url': 'https://api.github.com/users/wecode-bootcamp-korea/orgs',
#        'repos_url': 'https://api.github.com/users/wecode-bootcamp-korea/repos',
#        'events_url': 'https://api.github.com/users/wecode-bootcamp-korea/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/wecode-bootcamp-korea/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/wecode-bootcamp-korea/westagram-backend',
#       'description': 'Backend | Westagram',
#       'fork': False,
#       'url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend',
#       'forks_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/forks',
#       'keys_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/teams',
#       'hooks_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/hooks',
#       'issue_events_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/events',
#       'assignees_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/tags',
#       'blobs_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/languages',
#       'stargazers_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/stargazers',
#       'contributors_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/contributors',
#       'subscribers_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/subscribers',
#       'subscription_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/subscription',
#       'commits_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/merges',
#       'archive_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/downloads',
#       'issues_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/deployments',
#       'created_at': '2020-07-06T10:58:45Z',
#       'updated_at': '2021-02-04T05:43:26Z',
#       'pushed_at': '2021-02-06T14:00:05Z',
#       'git_url': 'git://github.com/wecode-bootcamp-korea/westagram-backend.git',
#       'ssh_url': 'git@github.com:wecode-bootcamp-korea/westagram-backend.git',
#       'clone_url': 'https://github.com/wecode-bootcamp-korea/westagram-backend.git',
#       'svn_url': 'https://github.com/wecode-bootcamp-korea/westagram-backend',
#       'homepage': None,
#       'size': 2112,
#       'stargazers_count': 4,
#       'watchers_count': 4,
#       'language': 'Python',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 4,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 34,
#       'license': None,
#       'forks': 4,
#       'open_issues': 34,
#       'watchers': 4,
#       'default_branch': 'master'}},
#     'base': {'label': 'wecode-bootcamp-korea:master',
#      'ref': 'master',
#      'sha': 'c9df39b22dd2aff13411e354c363ee017b8f2100',
#      'user': {'login': 'wecode-bootcamp-korea',
#       'id': 52394741,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjUyMzk0NzQx',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/52394741?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/wecode-bootcamp-korea',
#       'html_url': 'https://github.com/wecode-bootcamp-korea',
#       'followers_url': 'https://api.github.com/users/wecode-bootcamp-korea/followers',
#       'following_url': 'https://api.github.com/users/wecode-bootcamp-korea/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/wecode-bootcamp-korea/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/wecode-bootcamp-korea/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/wecode-bootcamp-korea/subscriptions',
#       'organizations_url': 'https://api.github.com/users/wecode-bootcamp-korea/orgs',
#       'repos_url': 'https://api.github.com/users/wecode-bootcamp-korea/repos',
#       'events_url': 'https://api.github.com/users/wecode-bootcamp-korea/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/wecode-bootcamp-korea/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 277517763,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyNzc1MTc3NjM=',
#       'name': 'westagram-backend',
#       'full_name': 'wecode-bootcamp-korea/westagram-backend',
#       'private': False,
#       'owner': {'login': 'wecode-bootcamp-korea',
#        'id': 52394741,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjUyMzk0NzQx',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/52394741?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/wecode-bootcamp-korea',
#        'html_url': 'https://github.com/wecode-bootcamp-korea',
#        'followers_url': 'https://api.github.com/users/wecode-bootcamp-korea/followers',
#        'following_url': 'https://api.github.com/users/wecode-bootcamp-korea/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/wecode-bootcamp-korea/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/wecode-bootcamp-korea/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/wecode-bootcamp-korea/subscriptions',
#        'organizations_url': 'https://api.github.com/users/wecode-bootcamp-korea/orgs',
#        'repos_url': 'https://api.github.com/users/wecode-bootcamp-korea/repos',
#        'events_url': 'https://api.github.com/users/wecode-bootcamp-korea/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/wecode-bootcamp-korea/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/wecode-bootcamp-korea/westagram-backend',
#       'description': 'Backend | Westagram',
#       'fork': False,
#       'url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend',
#       'forks_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/forks',
#       'keys_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/teams',
#       'hooks_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/hooks',
#       'issue_events_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/events',
#       'assignees_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/tags',
#       'blobs_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/languages',
#       'stargazers_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/stargazers',
#       'contributors_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/contributors',
#       'subscribers_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/subscribers',
#       'subscription_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/subscription',
#       'commits_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/merges',
#       'archive_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/downloads',
#       'issues_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/deployments',
#       'created_at': '2020-07-06T10:58:45Z',
#       'updated_at': '2021-02-04T05:43:26Z',
#       'pushed_at': '2021-02-06T14:00:05Z',
#       'git_url': 'git://github.com/wecode-bootcamp-korea/westagram-backend.git',
#       'ssh_url': 'git@github.com:wecode-bootcamp-korea/westagram-backend.git',
#       'clone_url': 'https://github.com/wecode-bootcamp-korea/westagram-backend.git',
#       'svn_url': 'https://github.com/wecode-bootcamp-korea/westagram-backend',
#       'homepage': None,
#       'size': 2112,
#       'stargazers_count': 4,
#       'watchers_count': 4,
#       'language': 'Python',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 4,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 34,
#       'license': None,
#       'forks': 4,
#       'open_issues': 34,
#       'watchers': 4,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/pulls/208'},
#      'html': {'href': 'https://github.com/wecode-bootcamp-korea/westagram-backend/pull/208'},
#      'issue': {'href': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/issues/208'},
#      'comments': {'href': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/issues/208/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/pulls/208/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/pulls/208/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/statuses/3c5fbe39e45529715998d870603c121aa780d4a3'}},
#     'author_association': 'NONE',
#     'auto_merge': None,
#     'active_lock_reason': None}},
#   'public': True,
#   'created_at': '2021-02-07T06:23:04Z',
#   'org': {'id': 52394741,
#    'login': 'wecode-bootcamp-korea',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/wecode-bootcamp-korea',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/52394741?'}},
#  {'id': '15094438009',
#   'type': 'CreateEvent',
#   'actor': {'id': 37783883,
#    'login': 'UoooBarry',
#    'display_login': 'UoooBarry',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/UoooBarry',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/37783883?'},
#   'repo': {'id': 336180435,
#    'name': 'UoooBarry/python-fedex-tracking-lambda-function',
#    'url': 'https://api.github.com/repos/UoooBarry/python-fedex-tracking-lambda-function'},
#   'payload': {'ref': 'shortant-code',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'A simple python lambda function that could track a FedEx package with a tracking number',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-02-07T06:23:26Z'},
#  {'id': '15094438002',
#   'type': 'PullRequestReviewCommentEvent',
#   'actor': {'id': 14783759,
#    'login': 'ulfrid',
#    'display_login': 'ulfrid',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ulfrid',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/14783759?'},
#   'repo': {'id': 277517763,
#    'name': 'wecode-bootcamp-korea/westagram-backend',
#    'url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend'},
#   'payload': {'action': 'created',
#    'comment': {'url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/pulls/comments/571558423',
#     'pull_request_review_id': 584969447,
#     'id': 571558423,
#     'node_id': 'MDI0OlB1bGxSZXF1ZXN0UmV2aWV3Q29tbWVudDU3MTU1ODQyMw==',
# ...
#       'issue_events_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/events',
#       'assignees_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/tags',
#       'blobs_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/languages',
#       'stargazers_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/stargazers',
#       'contributors_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/contributors',
#       'subscribers_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/subscribers',
#       'subscription_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/subscription',
#       'commits_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/merges',
#       'archive_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/downloads',
#       'issues_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/deployments',
#       'created_at': '2020-07-06T10:58:45Z',
#       'updated_at': '2021-02-04T05:43:26Z',
#       'pushed_at': '2021-02-06T14:00:05Z',
#       'git_url': 'git://github.com/wecode-bootcamp-korea/westagram-backend.git',
#       'ssh_url': 'git@github.com:wecode-bootcamp-korea/westagram-backend.git',
#       'clone_url': 'https://github.com/wecode-bootcamp-korea/westagram-backend.git',
#       'svn_url': 'https://github.com/wecode-bootcamp-korea/westagram-backend',
#       'homepage': None,
#       'size': 2112,
#       'stargazers_count': 4,
#       'watchers_count': 4,
#       'language': 'Python',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 4,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 34,
#       'license': None,
#       'forks': 4,
#       'open_issues': 34,
#       'watchers': 4,
#       'default_branch': 'master'}},
#     'base': {'label': 'wecode-bootcamp-korea:master',
#      'ref': 'master',
#      'sha': 'c9df39b22dd2aff13411e354c363ee017b8f2100',
#      'user': {'login': 'wecode-bootcamp-korea',
#       'id': 52394741,
#       'node_id': 'MDEyOk9yZ2FuaXphdGlvbjUyMzk0NzQx',
#       'avatar_url': 'https://avatars.githubusercontent.com/u/52394741?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/wecode-bootcamp-korea',
#       'html_url': 'https://github.com/wecode-bootcamp-korea',
#       'followers_url': 'https://api.github.com/users/wecode-bootcamp-korea/followers',
#       'following_url': 'https://api.github.com/users/wecode-bootcamp-korea/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/wecode-bootcamp-korea/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/wecode-bootcamp-korea/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/wecode-bootcamp-korea/subscriptions',
#       'organizations_url': 'https://api.github.com/users/wecode-bootcamp-korea/orgs',
#       'repos_url': 'https://api.github.com/users/wecode-bootcamp-korea/repos',
#       'events_url': 'https://api.github.com/users/wecode-bootcamp-korea/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/wecode-bootcamp-korea/received_events',
#       'type': 'Organization',
#       'site_admin': False},
#      'repo': {'id': 277517763,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkyNzc1MTc3NjM=',
#       'name': 'westagram-backend',
#       'full_name': 'wecode-bootcamp-korea/westagram-backend',
#       'private': False,
#       'owner': {'login': 'wecode-bootcamp-korea',
#        'id': 52394741,
#        'node_id': 'MDEyOk9yZ2FuaXphdGlvbjUyMzk0NzQx',
#        'avatar_url': 'https://avatars.githubusercontent.com/u/52394741?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/wecode-bootcamp-korea',
#        'html_url': 'https://github.com/wecode-bootcamp-korea',
#        'followers_url': 'https://api.github.com/users/wecode-bootcamp-korea/followers',
#        'following_url': 'https://api.github.com/users/wecode-bootcamp-korea/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/wecode-bootcamp-korea/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/wecode-bootcamp-korea/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/wecode-bootcamp-korea/subscriptions',
#        'organizations_url': 'https://api.github.com/users/wecode-bootcamp-korea/orgs',
#        'repos_url': 'https://api.github.com/users/wecode-bootcamp-korea/repos',
#        'events_url': 'https://api.github.com/users/wecode-bootcamp-korea/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/wecode-bootcamp-korea/received_events',
#        'type': 'Organization',
#        'site_admin': False},
#       'html_url': 'https://github.com/wecode-bootcamp-korea/westagram-backend',
#       'description': 'Backend | Westagram',
#       'fork': False,
#       'url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend',
#       'forks_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/forks',
#       'keys_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/keys{/key_id}',
#       'collaborators_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/collaborators{/collaborator}',
#       'teams_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/teams',
#       'hooks_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/hooks',
#       'issue_events_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/events',
#       'assignees_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/tags',
#       'blobs_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/languages',
#       'stargazers_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/stargazers',
#       'contributors_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/contributors',
#       'subscribers_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/subscribers',
#       'subscription_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/subscription',
#       'commits_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/merges',
#       'archive_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/downloads',
#       'issues_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/deployments',
#       'created_at': '2020-07-06T10:58:45Z',
#       'updated_at': '2021-02-04T05:43:26Z',
#       'pushed_at': '2021-02-06T14:00:05Z',
#       'git_url': 'git://github.com/wecode-bootcamp-korea/westagram-backend.git',
#       'ssh_url': 'git@github.com:wecode-bootcamp-korea/westagram-backend.git',
#       'clone_url': 'https://github.com/wecode-bootcamp-korea/westagram-backend.git',
#       'svn_url': 'https://github.com/wecode-bootcamp-korea/westagram-backend',
#       'homepage': None,
#       'size': 2112,
#       'stargazers_count': 4,
#       'watchers_count': 4,
#       'language': 'Python',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 4,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 34,
#       'license': None,
#       'forks': 4,
#       'open_issues': 34,
#       'watchers': 4,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/pulls/208'},
#      'html': {'href': 'https://github.com/wecode-bootcamp-korea/westagram-backend/pull/208'},
#      'issue': {'href': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/issues/208'},
#      'comments': {'href': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/issues/208/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/pulls/208/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/pulls/208/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/wecode-bootcamp-korea/westagram-backend/statuses/3c5fbe39e45529715998d870603c121aa780d4a3'}},
#     'author_association': 'NONE',
#     'auto_merge': None,
#     'active_lock_reason': None}},
#   'public': True,
#   'created_at': '2021-02-07T06:23:26Z',
#   'org': {'id': 52394741,
#    'login': 'wecode-bootcamp-korea',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/wecode-bootcamp-korea',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/52394741?'}},
#  {'id': '15094437994',
#   'type': 'CreateEvent',
#   'actor': {'id': 49275095,
#    'login': 'ursabot',
#    'display_login': 'ursabot',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ursabot',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/49275095?'},
#   'repo': {'id': 328697653,
#    'name': 'ursacomputing/crossbow',
#    'url': 'https://api.github.com/repos/ursacomputing/crossbow'},
#   'payload': {'ref': 'nightly-2021-02-07-0-github-test-conda-python-3.7-spark-branch-3.0',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': 'Extra CI for Apache Arrow',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2021-02-07T06:23:26Z',
#   'org': {'id': 70039053,
#    'login': 'ursacomputing',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/ursacomputing',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/70039053?'}},
#  {'id': '15094437988',
#   'type': 'PushEvent',
#   'actor': {'id': 4015312,
#    'login': 'locus313',
#    'display_login': 'locus313',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/locus313',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/4015312?'},
#   'repo': {'id': 276989111,
#    'name': 'locus313/azerothcore-wotlk',
#    'url': 'https://api.github.com/repos/locus313/azerothcore-wotlk'},
#   'payload': {'push_id': 6488318736,
#    'size': 2,
#    'distinct_size': 0,
#    'ref': 'refs/heads/dev-staging',
#    'head': 'd902411171fef250f842b304bc6c3eeaecab9463',
#    'before': 'c3a83c3618c4ccc1af19547a024c5c87c5beb145',
#    'commits': [{'sha': 'e7bfbe76510f496d49b3d54f64385d0557ecadec',
#      'author': {'email': 'footman@hotmail.de', 'name': 'Footman'},
#      'message': 'fix(Core/Pathfinding): pets chase & transport (#4451)',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/locus313/azerothcore-wotlk/commits/e7bfbe76510f496d49b3d54f64385d0557ecadec'},
#     {'sha': 'd902411171fef250f842b304bc6c3eeaecab9463',
#      'author': {'email': '24550914+Kitzunu@users.noreply.github.com',
#       'name': 'Kitzunu'},
#      'message': 'fix(Core/Spell): Clearcasting duration (#4422)',
#      'distinct': False,
#      'url': 'https://api.github.com/repos/locus313/azerothcore-wotlk/commits/d902411171fef250f842b304bc6c3eeaecab9463'}]},
#   'public': True,
#   'created_at': '2021-02-07T06:23:26Z'}]

# %% [markdown]
# * 1.r.text:較為凌亂，不容易閱讀
# * 2.json.loads(r.text):以dict的方式整理，較容易閱讀

# %% [markdown]
# ### 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#
# * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
# * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)

# %%
import requests
import json
r = requests.get('https://cat-fact.herokuapp.com/facts')
json.loads(r.text)
# Out:
# [{'status': {'verified': True, 'sentCount': 1, 'feedback': ''},
#   'type': 'cat',
#   'deleted': False,
#   '_id': '5887e1d85c873e0011036889',
#   'user': '5a9ac18c7478810ea6c06381',
#   'text': 'Cats make about 100 different sounds. Dogs make only about 10.',
#   '__v': 0,
#   'source': 'user',
#   'updatedAt': '2020-09-03T16:39:39.578Z',
#   'createdAt': '2018-01-15T21:20:00.003Z',
#   'used': True},
#  {'status': {'verified': True, 'sentCount': 1},
#   'type': 'cat',
#   'deleted': False,
#   '_id': '588e746706ac2b00110e59ff',
#   'user': '588e6e8806ac2b00110e59c3',
#   'text': 'Domestic cats spend about 70 percent of the day sleeping and 15 percent of the day grooming.',
#   '__v': 0,
#   'source': 'user',
#   'updatedAt': '2020-08-26T20:20:02.359Z',
#   'createdAt': '2018-01-14T21:20:02.750Z',
#   'used': True},
#  {'status': {'verified': True, 'sentCount': 1},
#   'type': 'cat',
#   'deleted': False,
#   '_id': '58923f2fc3878c0011784c79',
#   'user': '5887e9f65c873e001103688d',
#   'text': "I don't know anything about cats.",
#   '__v': 0,
#   'source': 'user',
#   'updatedAt': '2020-08-23T20:20:01.611Z',
#   'createdAt': '2018-02-25T21:20:03.060Z',
#   'used': False},
#  {'status': {'verified': True, 'sentCount': 1},
#   'type': 'cat',
#   'deleted': False,
#   '_id': '5894af975cdc7400113ef7f9',
#   'user': '5a9ac18c7478810ea6c06381',
#   'text': 'The technical term for a cat’s hairball is a bezoar.',
#   '__v': 0,
#   'source': 'user',
#   'updatedAt': '2020-11-25T21:20:03.895Z',
#   'createdAt': '2018-02-27T21:20:02.854Z',
#   'used': True},
#  {'status': {'verified': True, 'sentCount': 1},
#   'type': 'cat',
#   'deleted': False,
#   '_id': '58e007cc0aac31001185ecf5',
#   'user': '58e007480aac31001185ecef',
#   'text': 'Cats are the most popular pet in the United States: There are 88 million pet cats and 74 million dogs.',
#   '__v': 0,
#   'source': 'user',
#   'updatedAt': '2020-08-23T20:20:01.611Z',
#   'createdAt': '2018-03-01T21:20:02.713Z',
#   'used': False}]
